# %% [markdown]
# ### How similar in ratings the movies with the most similar plots?

# %%
import pickle
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
#Loading data 
pkl_file = open('filtered_movies.pkl', 'rb')
col_movies = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('filtered_movies_content.pkl', 'rb')
con_movies = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('collaborative_decomposed_data.pkl', 'rb')
col_decomposed = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('content_decomposed_data.pkl', 'rb')
con_decomposed = pickle.load(pkl_file)
pkl_file.close()


pkl_file = open('con_highests.pkl', 'rb')
con_high = pickle.load(pkl_file)
pkl_file.close()

# %% [markdown]
# #### Finding the rating similarity of the movies with the most similar plots

# %%
class movie_similarity_lookup(object):
    """
    This class calculates the cosine distance of one row from all other rows in a matrix.
    
    Args:
    dataframe (dataframe): a dataframe with the column 'movie_title' containting the movie titles 
                           and indexed in the same order as the decomposed_data matrix
    decomposed_data (array): a numpy array with rows for movies and columns for user ratings after dimensionality reduction
    """
    def __init__(self, dataframe, decomposed_data):
        self.dataframe = dataframe
        self.decomposed_data = decomposed_data
        
    def similarity(self,row):
         """
        This method finds the cosine similarity between the decopmposed vectors of the movies.
        
        Args:
        row (pandas.Series): a pandas.Series containing values for title1 and title2
        
        Return:
        Cosine similarity as float
        """
        movie_index1 = self.dataframe[self.dataframe.movie_title==row.title1].index[0]
        movie_index2 = self.dataframe[self.dataframe.movie_title==row.title2].index[0]
        v1 = self.decomposed_data[movie_index1,:].reshape(1, -1)
        v2 = self.decomposed_data[movie_index2,:].reshape(1, -1)
        return round(cosine_similarity(v1,v2),3)

# %%
m = movie_similarity_lookup(col_movies,col_decomposed)

# %%
df = pd.DataFrame(con_high, columns=['con_sim','title1','title2'])

df['col_sim'] = df.apply(lambda x:m.similarity(x), axis=1)

df['diff'] = df['con_sim'] - df['col_sim']

# %% [markdown]
# ### The movies which are very similar based on their plots but different based on the ratings  - Remakes

# %%
df.sort_values('diff', ascending=False).head(20)
# Out:
#       con_sim                             title1  \
# 4338    1.000                      Curfew (2012)
# 2222    1.000          Before I Disappear (2014)
# 2882    0.864                   Excalibur (1981)
# 3871    0.864                 King Arthur (2004)
# 506     0.844     The Talented Mr. Ripley (1999)
# 3812    0.844                Plein soleil (1960)
# 5732    0.824                American Pie (1999)
# 1891    0.824             Date and Switch (2014)
# 3657    0.816                     Mascots (2016)
# 5283    0.816                   Surf's Up (2007)
# 3252    0.830                     Dracula (1958)
# 3993    0.805            A Perfect Murder (1998)
# 1788    0.805                High Anxiety (1977)
# 3999    0.832                         Pan (2015)
# 2276    0.832                   Peter Pan (1953)
# 5688    0.920                   True Grit (1969)
# 4857    0.920                   True Grit (2010)
# 5641    0.786               Runaway Bride (1999)
# 3283    0.786  No se Aceptan Devoluciones (2013)
# 3391    0.790                     Ronaldo (2015)
#
#                                    title2  col_sim   diff
# 4338            Before I Disappear (2014)    0.107  0.893
# 2222                        Curfew (2012)    0.107  0.893
# 2882                   King Arthur (2004)    0.010  0.854
# 3871                     Excalibur (1981)    0.010  0.854
# 506                   Plein soleil (1960)    0.002  0.842
# 3812       The Talented Mr. Ripley (1999)    0.002  0.842
# 5732               Date and Switch (2014)   -0.007  0.831
# 1891                  American Pie (1999)   -0.007  0.831
# 3657                     Surf's Up (2007)    0.004  0.812
# 5283                       Mascots (2016)    0.004  0.812
# 3252  Nosferatu: Phantom der Nacht (1979)    0.019  0.811
# 3993                  High Anxiety (1977)    0.002  0.803
# 1788              A Perfect Murder (1998)    0.002  0.803
# 3999                     Peter Pan (1953)    0.037  0.795
# 2276                           Pan (2015)    0.037  0.795
# 5688                     True Grit (2010)    0.126  0.794
# 4857                     True Grit (1969)    0.126  0.794
# 5641    No se Aceptan Devoluciones (2013)   -0.001  0.787
# 3283                 Runaway Bride (1999)   -0.001  0.787
# 3391                        iSteve (2013)    0.011  0.779

# %% [markdown]
# ### Movies with very similar ratings but with different plots - Movie series

# %%
df.sort_values('diff', ascending=True).head(20)
# Out:
#       con_sim                                             title1  \
# 1976    0.365                        The Bourne Supremacy (2004)
# 2549    0.365                        The Bourne Ultimatum (2007)
# 2529    0.368             Rurôni Kenshin: Kyôto Taika-hen (2014)
# 5661    0.412                             Lethal Weapon 2 (1989)
# 3857    0.389        Indiana Jones and the Temple of Doom (1984)
# 3038    0.418                           Kill Bill: Vol. 2 (2004)
# 3977    0.519  The Lord of the Rings: The Fellowship of the R...
# 576     0.541       The Lord of the Rings: The Two Towers (2002)
# 575     0.541  The Lord of the Rings: The Return of the King ...
# 849     0.413                             Sherlock Holmes (2009)
# 3236    0.492                                   Moonraker (1979)
# 5519    0.391                    X-Men Origins: Wolverine (2009)
# 4377    0.559      Harry Potter and the Half-Blood Prince (2009)
# 141     0.405                 Back to the Future Part III (1990)
# 4130    0.405                          Back to the Future (1985)
# 4176    0.606  Star Wars: Episode II - Attack of the Clones (...
# 1029    0.490                      The Godfather: Part II (1974)
# 225     0.490                     The Godfather: Part III (1990)
# 1452    0.496                       Underworld: Evolution (2006)
# 2469    0.431                  Die Hard: With a Vengeance (1995)
#
#                                                  title2  col_sim   diff
# 1976                        The Bourne Ultimatum (2007)    0.876 -0.511
# 2549                        The Bourne Supremacy (2004)    0.876 -0.511
# 2529            Rurouni Kenshin: The Legend Ends (2014)    0.836 -0.468
# 5661                             Lethal Weapon 3 (1992)    0.860 -0.448
# 3857          Indiana Jones and the Last Crusade (1989)    0.815 -0.426
# 3038                           Kill Bill: Vol. 1 (2003)    0.831 -0.413
# 3977       The Lord of the Rings: The Two Towers (2002)    0.930 -0.411
# 576   The Lord of the Rings: The Return of the King ...    0.949 -0.408
# 575        The Lord of the Rings: The Two Towers (2002)    0.949 -0.408
# 849           Sherlock Holmes: A Game of Shadows (2011)    0.801 -0.388
# 3236                        The Spy Who Loved Me (1977)    0.875 -0.383
# 5519                                          X2 (2003)    0.771 -0.380
# 4377         Harry Potter and the Goblet of Fire (2005)    0.931 -0.372
# 141                           Back to the Future (1985)    0.770 -0.365
# 4130                 Back to the Future Part III (1990)    0.770 -0.365
# 4176  Star Wars: Episode III - Revenge of the Sith (...    0.941 -0.335
# 1029                     The Godfather: Part III (1990)    0.819 -0.329
# 225                       The Godfather: Part II (1974)    0.819 -0.329
# 1452                       Underworld: Awakening (2012)    0.824 -0.328
# 2469                       Live Free or Die Hard (2007)    0.754 -0.323
